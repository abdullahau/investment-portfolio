# %% [markdown]
# ## Main Script

# %%
import re
import json
import pandas as pd
import pdfplumber
from collections import defaultdict
from pathlib import Path


def extract_period_from_text(text):
    """Extracts the statement period (e.g., '2025-June') from the first page text."""
    match = re.search(r"Period:\s+([A-Z]+)\s+-\s+(\d{4})", text)
    if match:
        month = match.group(1).capitalize()
        year = match.group(2)
        return f"{year}-{month}"
    return None


def clean_header(header):
    # Removes \n, trims spaces, and joins words cleanly
    return [col.replace("\n", " ").strip() for col in header]


def process_single_statement(file_path):
    """
    Parses a single statement PDF, sets correct data types, and extracts the period.
    Returns the period string and a dictionary of DataFrames.
    """
    TABLE_NAMES = ["Holdings", "Income", "Fees", "Transaction", "Deposit & Withdrawals"]
    NUMERIC_COLS = [
        "Net Amt",
        "Amount",
        "Market Price",
        "Market Value",
        "Cost Price",
        "Unrealized",
        "TD Cost Basis",
        "Commission",
        "Price",
        "Quantity",
    ]
    DATE_COLS = ["Trade Date"]  # Add any other date columns here

    data_collector = defaultdict(list)
    current_table_name = None
    statement_period = None

    with pdfplumber.open(file_path) as pdf:
        # Extract period from the first page
        first_page_text = pdf.pages[0].extract_text()
        statement_period = extract_period_from_text(first_page_text)

        for page in pdf.pages:
            for table in page.extract_tables():
                for row in table:
                    if not any(cell for cell in row if cell and cell.strip()):
                        continue
                    first_cell = row[0].strip() if row[0] else ""
                    if first_cell in TABLE_NAMES:
                        current_table_name = first_cell
                        continue
                    if current_table_name:
                        if "No record found." in first_cell:
                            current_table_name = None
                            continue
                        data_collector[current_table_name].append(row)

    final_dfs = {}
    for name, rows in data_collector.items():
        if not rows:
            continue
        header = clean_header(rows[0])
        data = [row for row in rows[1:] if row != header]
        if not data:
            continue

        df = pd.DataFrame(data, columns=header)
        df.replace(["-", "--", "$ --", "$--", ""], pd.NA, inplace=True)

        for col in df.columns:
            # Convert numeric columns to float64
            if col in NUMERIC_COLS:
                df[col] = pd.to_numeric(
                    df[col]
                    .astype(str)
                    .str.replace("\n", "", regex=False)
                    .str.replace(" ", "", regex=False)
                    .str.replace("$", "", regex=False)
                    .str.replace(",", "", regex=False)
                    .str.replace("(", "-", regex=False)
                    .str.replace(")", "", regex=False),
                    errors="coerce",
                )

            # Convert date columns to datetime
            elif col in DATE_COLS:
                df[col] = pd.to_datetime(df[col], errors="coerce")

        # All other columns remain as 'object' (string) type by default
        final_dfs[name] = df

    return statement_period, final_dfs


def process_all_statements(input_folder, output_file):
    """
    Processes all PDF statements in a folder and saves the aggregated data to a single JSON file.
    """
    all_data = {}
    folder_path = Path(input_folder)
    pdf_files = list(folder_path.glob("*.pdf"))

    print(f"Found {len(pdf_files)} PDF files to process...")

    for pdf_file in pdf_files:
        print(f"Processing {pdf_file.name}...")
        period, dfs = process_single_statement(pdf_file)
        if period:
            # Convert DataFrames to JSON-serializable format (list of dicts)
            # and handle datetime conversion to string format for JSON
            all_data[period] = {
                name: json.loads(df.to_json(orient="records", date_format="iso"))
                for name, df in dfs.items()
            }
        else:
            print(
                f"  - Warning: Could not extract period from {pdf_file.name}. Skipping."
            )

    # Save the master dictionary to a single JSON file
    with open(output_file, "w") as f:
        json.dump(all_data, f, indent=4)

    print(f"\nAll data successfully saved to {output_file}")

# %% [markdown]
# ## Process Statements & Store as JSON

# %%
process_all_statements(
    input_folder="raw-data/monthly-statements-pdf", output_file="raw-data/brokerage_data.json"
)
# Out:
# Found 29 PDF files to process...
# Processing April2025.pdf...
# Processing October2023.pdf...
# Processing April2024.pdf...
# Processing April2023.pdf...
# Processing October2024.pdf...
# Processing July2023.pdf...
# Processing September2023.pdf...
# Processing September2024.pdf...
# Processing July2024.pdf...
# Processing May2023.pdf...
# Processing March2023.pdf...
# Processing November2024.pdf...
# Processing January2024.pdf...
# Processing March2024.pdf...
# Processing May2024.pdf...
# Processing May2025.pdf...
# Processing March2025.pdf...
# Processing January2025.pdf...
# Processing November2023.pdf...
# Processing June2025.pdf...
# Processing June2024.pdf...
# Processing December2023.pdf...
# Processing August2023.pdf...
# Processing February2023.pdf...
# Processing June2023.pdf...
# Processing February2024.pdf...
# Processing February2025.pdf...
# Processing August2024.pdf...
# Processing December2024.pdf...
#
# All data successfully saved to brokerage_data.json

# %% [markdown]
# ## Example Code: Read & Load JSON

# %%
import json
import pandas as pd

with open("raw-data/brokerage_data.json", "r") as f:
    loaded_data = json.load(f)

# Example: Get the Holdings DataFrame for December 2024
pd.DataFrame(loaded_data["2024-December"]["Holdings"])
# Out:
#    Symbol                                  Description  Quantity  \
# 0   *Cash                                          USD       NaN
# 1    AMZN                           AMAZON COM INC COM  0.149980
# 2     APO                   APOLLO GLOBAL MGMT INC COM  0.273329
# 3     ARM               ARM HOLDINGS PLC SPONSORED ADS  0.080826
# 4     BRW       SABA CAPITAL INCOME & OPRNT FD SHS NEW  4.707718
# 5    CEFS         EXCHANGE LISTED FDS TR SABA INT RATE  1.114267
# 6     CLM           CORNERSTONE STRATEGIC INVESTME COM  2.816941
# 7     GOF        GUGGENHEIM STRATEGIC OPPORTUN COM SBI  3.000000
# 8    GSBD                    GOLDMAN SACHS BDC INC SHS  2.436461
# 9     IBB                   ISHARES TR ISHARES BIOTECH  0.047022
# 10    IJR                  ISHARES TR CORE S&P SCP ETF  0.227215
# 11   INDA                    ISHARES TR MSCI INDIA ETF  0.877661
# 12    IPO        RENAISSANCE CAP GREENWICH FDS IPO ETF  1.288476
# 13   JPMB  J P MORGAN EXCHANGE TRADED FD USD EMRNG MKT  1.688699
# 14    KKR                             KKR & CO INC COM  0.378202
# 15    LLY                           ELI LILLY & CO COM  0.062060
# 16    LUX                    TEMA ETF TRUST LUXURY ETF  2.000000
# 17   META                      META PLATFORMS INC CL A  0.138582
# 18   MOAT            VANECK ETF TRUST MRNGSTR WDE MOAT  0.544790
# 19   MSFT                           MICROSOFT CORP COM  0.255834
# 20   NVDA                       NVIDIA CORPORATION COM  0.250397
# 21   OCSL           OAKTREE SPECIALTY LENDING CORP COM  1.042269
# 22  RYAAY           RYANAIR HOLDINGS PLC SPONSORED ADR  0.315593
# 23   SMOT            VANECK ETF TRUST MORNINGSTAR SMID  0.718432
# 24    SPY                  SPDR S&P 500 ETF TR TR UNIT  0.177676
# 25   TPVG           TRIPLEPOINT VENTURE GROWTH BDC COM  4.000000
# 26   USRT                  ISHARES TR CRE U S REIT ETF  0.167590
# 27    VOO           VANGUARD INDEX FDS S&P 500 ETF SHS  1.066389
# 28   VOOG      VANGUARD ADMIRAL FDS INC 500 GRTH IDX F  0.346276
# 29   VXUS           VANGUARD STAR FDS VG TL INTL STK F  0.716810
# 30    XLF              SELECT SECTOR SPDR TR FINANCIAL  1.309464
# 31    XLK             SELECT SECTOR SPDR TR TECHNOLOGY  1.223873
#
#     Market Price  Market Value  Cost Price  Unrealized  TD Cost Basis
# 0            NaN          4.64         NaN         NaN            NaN
# 1         219.39         32.90      148.15       10.68          22.22
# 2         165.16         45.14      125.12       10.94          34.20
# 3         123.36          9.97      185.58       -5.03          15.00
# 4           7.62         35.87        7.43        0.87          35.00
# 5          21.42         23.87       17.95        3.87          20.00
# 6           8.59         24.20        7.10        4.20          20.00
# 7          15.26         45.78       13.42        5.51          40.27
# 8          12.10         29.48       14.37       -5.52          35.00
# 9         132.21          6.22      126.75        0.26           5.96
# 10        115.22         26.18      110.03        1.18          25.00
# 11         52.64         46.20       52.79       -0.13          46.33
# 12         43.57         56.14       40.97        3.35          52.79
# 13         38.04         64.24       40.55       -4.23          68.47
# 14        147.91         55.94      140.14        2.94          53.00
# 15        772.00         47.91      604.25       10.41          37.50
# 16         22.00         44.00       22.73       -1.46          45.45
# 17        585.51         81.14      305.52       38.80          42.34
# 18         92.73         50.52       93.61       -0.48          51.00
# 19        421.50        107.83      378.64       10.96          96.87
# 20        134.29         33.63      138.50       -1.05          34.68
# 21         15.28         15.93       19.53       -4.43          20.36
# 22         43.59         13.76       47.53       -1.24          15.00
# 23         34.47         24.76       34.80       -0.24          25.00
# 24        586.08        104.13      436.36       26.60          77.53
# 25          7.38         29.52       10.23      -11.41          40.93
# 26         57.31          9.60       50.36        1.16           8.44
# 27        538.81        574.58      493.41       48.41         526.17
# 28        366.06        126.76      267.79       34.03          92.73
# 29         58.93         42.24       59.99       -0.76          43.00
# 30         48.33         63.29       44.28        5.31          57.98
# 31        232.52        284.58      204.96       33.73         250.84

# %% [markdown]
# ## Inspect Single Statement Dataframes

# %%
december2024 = process_single_statement("raw-data/monthly-statements-pdf/August2024.pdf")[1]
december2024["Holdings"]
# Out:
#    Symbol                              Description  Quantity  Market Price  \
# 0   *Cash                                      USD       NaN           NaN
# 1    AMZN                       AMAZON COM INC COM  0.149980        178.50
# 2    ARKK                ARK ETF TR INNOVATION ETF  0.593922         44.82
# 3     ARM           ARM HOLDINGS PLC SPONSORED ADS  0.080826        132.88
# 4     BRW   SABA CAPITAL INCOME & OPRNT FD SHS NEW  4.707718          7.40
# 5    CEFS     EXCHANGE LISTED FDS TR SABA INT RATE  1.114267         21.82
# 6     CLM       CORNERSTONE STRATEGIC VALUE FD COM  2.816941          7.59
# 7     EWJ             ISHARES INC MSCI JPN ETF NEW  0.194821         71.97
# 8     GOF    GUGGENHEIM STRATEGIC OPPORTUN COM SBI  3.000000         15.45
# 9    GSBD                GOLDMAN SACHS BDC INC SHS  2.436461         14.13
# 10    IBB               ISHARES TR ISHARES BIOTECH  0.047022        148.17
# 11    IJR              ISHARES TR CORE S&P SCP ETF  0.227215        116.50
# 12   INDA                ISHARES TR MSCI INDIA ETF  0.877661         57.72
# 13    IPO    RENAISSANCE CAP GREENWICH FDS IPO ETF  0.803650         41.77
# 14    LLY                       ELI LILLY & CO COM  0.062060        960.02
# 15    LUX                TEMA ETF TRUST LUXURY ETF  2.000000         23.43
# 16   META                  META PLATFORMS INC CL A  0.138582        521.31
# 17   MSFT                       MICROSOFT CORP COM  0.128277        417.14
# 18   NOBL            PROSHARES TR S&P 500 DV ARIST  0.622737        104.81
# 19   OCSL       OAKTREE SPECIALTY LENDING CORP COM  1.042269         17.13
# 20    ROM             PROSHARES TR PSHS ULTRA TECH  0.343370         64.53
# 21  RYAAY       RYANAIR HOLDINGS PLC SPONSORED ADS  0.126237        111.46
# 22   SPHY             SPDR SER TR PORTFLI HIGH YLD  0.374850         23.80
# 23    SPY              SPDR S&P 500 ETF TR TR UNIT  0.177676        563.68
# 24   STIP               ISHARES TR 0-5 YR TIPS ETF  0.087386        100.37
# 25   TPVG       TRIPLEPOINT VENTURE GROWTH BDC COM  4.000000          7.53
# 26   TQQQ                PROSHARES TR ULTRAPRO QQQ  0.777963         68.61
# 27   USRT              ISHARES TR CRE U S REIT ETF  0.167590         60.53
# 28    VBK        VANGUARD INDEX FDS SML CP GRW ETF  0.101931        261.38
# 29    VOO       VANGUARD INDEX FDS S&P 500 ETF SHS  0.524587        518.04
# 30   VOOG  VANGUARD ADMIRAL FDS INC 500 GRTH IDX F  0.346276        336.11
# 31   VXUS       VANGUARD STAR FDS VG TL INTL STK F  0.716810         63.37
# 32    XLF          SELECT SECTOR SPDR TR FINANCIAL  0.794616         45.74
# 33    XLK         SELECT SECTOR SPDR TR TECHNOLOGY  1.011765        220.33
#
#     Market Value  Cost Price  Unrealized  TD Cost Basis
# 0           1.01         NaN         NaN            NaN
# 1          26.77      148.15        4.55          22.22
# 2          26.62       48.83       -2.38          29.00
# 3          10.74      185.58       -4.26          15.00
# 4          34.84        7.43       -0.16          35.00
# 5          24.31       17.95        4.31          20.00
# 6          21.38        7.10        1.38          20.00
# 7          14.02       64.11        1.53          12.49
# 8          46.35       13.42        6.08          40.27
# 9          34.43       14.37       -0.57          35.00
# 10          6.97      126.75        1.01           5.96
# 11         26.47      110.03        1.47          25.00
# 12         50.66       52.79        4.33          46.33
# 13         33.57       38.57        2.57          31.00
# 14         59.58      604.25       22.08          37.50
# 15         46.86       22.73        1.41          45.45
# 16         72.24      305.52       29.90          42.34
# 17         53.51      337.47       10.22          43.29
# 18         65.27       92.61        7.60          57.67
# 19         17.85       19.53       -2.51          20.36
# 20         22.16       76.65       -4.16          26.32
# 21         14.07      118.82       -0.93          15.00
# 22          8.92       22.60        0.45           8.47
# 23        100.15      436.36       22.62          77.53
# 24          8.77       97.04        0.29           8.48
# 25         30.12       10.23      -10.81          40.93
# 26         53.38       68.27        0.27          53.11
# 27         10.14       50.36        1.70           8.44
# 28         26.64      245.26        1.64          25.00
# 29        271.76      456.55       32.26         239.50
# 30        116.39      267.79       23.66          92.73
# 31         45.42       59.99        2.42          43.00
# 32         36.35       41.51        3.37          32.98
# 33        222.92      197.77       22.83         200.09
