# %%
import json
import pandas as pd

import sys
from pathlib import Path
sys.path.append(str(Path.cwd().parent))
import config

# %%
pd.read_csv(config.INPUT_DATA_DIR / "us_mkt_transactions.csv")
# Out:
#            Date          Type Symbol  Quantity       Price  Amount  \
# 0    2023-02-16   Net Deposit    NaN       NaN         NaN  271.57
# 1    2023-02-17           buy   PERI  0.407270   33.340000  -13.58
# 2    2023-02-17           buy   TSLA  0.202666  201.020000  -40.74
# 3    2023-02-17           buy    VOO  0.218967  372.070000  -81.47
# 4    2023-03-29  Net Dividend    VOO       NaN         NaN    0.24
# ..          ...           ...    ...       ...         ...     ...
# 551  2025-07-24   Net Deposit    NaN       NaN         NaN  271.57
# 552  2025-07-24           buy     BX  0.325800  178.023327  -58.00
# 553  2025-07-24           buy    APO  0.261400  153.022188  -40.00
# 554  2025-07-24           buy  BRK-B  0.124000  481.935484  -59.76
# 555  2025-07-28  Net Dividend   GSBD       NaN         NaN    0.82
#
#      Commission Currency                                        Description  \
# 0           NaN      USD  ID: 37fdafdc-d707-42fa-ba74-98b30cf9ab2a - DT2...
# ...

# %%
with open(config.SYMBOL_METADATA_CACHE_FILE, "r") as f:
    brokerage_data = json.load(f)
